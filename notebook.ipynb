# %% [markdown]
# # `Proyek Analisis Data: Bike Sharing Dataset`
#
# - **Nama:** Giri Firmansyah
# - **Email:** girifirmansyaaah14@gmail.com
# - **ID Dicoding:** CDCC004D6Y1385

# %% [markdown]
# # `Menentukan Pertanyaan Bisnis`
#
# SMART Question adalah framework untuk menyusun pertanyaan secara terstruktur agar memperoleh insight yang jelas dan dapat ditindaklanjuti.

# %% [markdown]
# ## Pertanyaan Bisnis 1
#
# Bagaimana pengaruh kondisi cuaca terhadap jumlah penyewaan sepeda pada tahun 2011–2012?
#
# ### SMART Analysis
#
# - **Specific:** Fokus pada hubungan kondisi cuaca dan jumlah penyewaan sepeda.
# - **Measurable:** Menggunakan rata-rata jumlah penyewaan sepeda.
# - **Action-Oriented:** Dapat digunakan untuk menentukan strategi promosi saat cuaca tertentu.
# - **Relevant:** Membantu perusahaan memahami perilaku pengguna.
# - **Time-Bound:** Dataset tahun 2011–2012.

# %% [markdown]
# ## Pertanyaan Bisnis 2
#
# Pada jam berapa jumlah penyewaan sepeda mencapai puncak tertinggi selama periode 2011–2012?
#
# ### SMART Analysis
#
# - **Specific:** Fokus pada jam penyewaan tertinggi.
# - **Measurable:** Menggunakan rata-rata penyewaan per jam.
# - **Action-Oriented:** Membantu optimalisasi jumlah sepeda pada jam tertentu.
# - **Relevant:** Mendukung efisiensi operasional bike sharing.
# - **Time-Bound:** Dataset tahun 2011–2012.

# %% [markdown]
# # `Import Semua Packages/Library yang Digunakan`

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style='whitegrid')

# %% [markdown]
# # `Data Wrangling`

# %% [markdown]
# ## Gathering Data
#
# Pada tahap ini dilakukan proses pengumpulan dataset yang akan digunakan untuk analisis.

# %%
day_df = pd.read_csv('data/day.csv')
hour_df = pd.read_csv('data/hour.csv')

# %%
day_df.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
hour_df.head()
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %% [markdown]
# ## Assessing Data
#
# Pada tahap ini dilakukan pengecekan kualitas data untuk menemukan permasalahan seperti missing value, duplicate data, dan kesalahan tipe data.

# %%
day_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    object
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: float64(4), int64(11), object(1)
# memory usage: 91.5+ KB

# %%
hour_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
print(day_df.isna().sum())
print('')
print(hour_df.isna().sum())
# Out:
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64
#
# instant       0
# dteday        0
# season        0
# yr            0
# mnth          0
# hr            0
# holiday       0
# weekday       0
# workingday    0
# weathersit    0
# temp          0
# atemp         0
# hum           0
# windspeed     0
# casual        0
# registered    0
# cnt           0
# dtype: int64

# %%
print('Jumlah duplicate data day_df:', day_df.duplicated().sum())
print('Jumlah duplicate data hour_df:', hour_df.duplicated().sum())
# Out:
# Jumlah duplicate data day_df: 0
# Jumlah duplicate data hour_df: 0

# %%
day_df.describe()
# Out:
#           instant      season          yr        mnth     holiday     weekday  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean   366.000000    2.496580    0.500684    6.519836    0.028728    2.997264
# std    211.165812    1.110807    0.500342    3.451913    0.167155    2.004787
# min      1.000000    1.000000    0.000000    1.000000    0.000000    0.000000
# 25%    183.500000    2.000000    0.000000    4.000000    0.000000    1.000000
# 50%    366.000000    3.000000    1.000000    7.000000    0.000000    3.000000
# 75%    548.500000    3.000000    1.000000   10.000000    0.000000    5.000000
# max    731.000000    4.000000    1.000000   12.000000    1.000000    6.000000
#
#        workingday  weathersit        temp       atemp         hum   windspeed  \
# count  731.000000  731.000000  731.000000  731.000000  731.000000  731.000000
# mean     0.683995    1.395349    0.495385    0.474354    0.627894    0.190486
# ...

# %% [markdown]
# ### Insight Assessing Data
#
# Berdasarkan hasil assessing data ditemukan beberapa masalah:
#
# 1. Kolom `dteday` masih bertipe object.
# 2. Terdapat duplicate data pada dataset.
#
# ### Solusi Cleaning
#
# 1. Mengubah tipe data `dteday` menjadi datetime.
# 2. Menghapus duplicate data.

# %% [markdown]
# ## Cleaning Data
#
# Tahap cleaning data dilakukan untuk memperbaiki masalah yang ditemukan pada proses assessing data.

# %%
# Mengubah tipe data

day_df['dteday'] = pd.to_datetime(day_df['dteday'])
hour_df['dteday'] = pd.to_datetime(hour_df['dteday'])

# %%
# Menghapus duplicate data

day_df.drop_duplicates(inplace=True)
hour_df.drop_duplicates(inplace=True)

# %%
print(day_df.info())
print('')
print(hour_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 731 entries, 0 to 730
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     731 non-null    int64
#  1   dteday      731 non-null    datetime64[ns]
#  2   season      731 non-null    int64
#  3   yr          731 non-null    int64
#  4   mnth        731 non-null    int64
#  5   holiday     731 non-null    int64
#  6   weekday     731 non-null    int64
#  7   workingday  731 non-null    int64
#  8   weathersit  731 non-null    int64
#  9   temp        731 non-null    float64
#  10  atemp       731 non-null    float64
#  11  hum         731 non-null    float64
#  12  windspeed   731 non-null    float64
#  13  casual      731 non-null    int64
#  14  registered  731 non-null    int64
#  15  cnt         731 non-null    int64
# dtypes: datetime64[ns](1), float64(4), int64(11)
# memory usage: 91.5 KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# ...

# %% [markdown]
# # `Exploratory Data Analysis (EDA)`

# %% [markdown]
# ## Explore Data Day Dataset
#
# Melakukan eksplorasi untuk mengetahui pola penyewaan sepeda berdasarkan kondisi cuaca.

# %%
weather_rentals = day_df.groupby('weathersit')['cnt'].mean().sort_values(ascending=False)
weather_rentals
# Out:
# weathersit
# 1    4876.786177
# 2    4035.862348
# 3    1803.285714
# Name: cnt, dtype: float64

# %% [markdown]
# ### Insight
#
# Kondisi cuaca cerah memiliki rata-rata jumlah penyewaan sepeda tertinggi dibanding kondisi cuaca lainnya.

# %% [markdown]
# ## Explore Data Hour Dataset
#
# Melakukan eksplorasi untuk mengetahui pola penyewaan sepeda berdasarkan jam.

# %%
hourly_rentals = hour_df.groupby('hr')['cnt'].mean()
hourly_rentals
# Out:
# hr
# 0      53.898072
# 1      33.375691
# 2      22.869930
# 3      11.727403
# 4       6.352941
# 5      19.889819
# 6      76.044138
# 7     212.064649
# 8     359.011004
# 9     219.309491
# 10    173.668501
# 11    208.143054
# 12    253.315934
# 13    253.661180
# 14    240.949246
# 15    251.233196
# 16    311.983562
# 17    461.452055
# 18    425.510989
# 19    311.523352
# 20    226.030220
# 21    172.314560
# 22    131.335165
# 23     87.831044
# Name: cnt, dtype: float64

# %% [markdown]
# ### Insight
#
# Jumlah penyewaan sepeda meningkat pada jam sibuk, terutama pagi dan sore hari.

# %% [markdown]
# # `Visualization & Explanatory Analysis`

# %% [markdown]
# ## Pertanyaan 1:
# Bagaimana pengaruh kondisi cuaca terhadap jumlah penyewaan sepeda?

# %%
weather_label = {
    1: 'Clear',
    2: 'Mist',
    3: 'Light Snow/Rain',
    4: 'Heavy Rain'
}

day_df['weather_label'] = day_df['weathersit'].map(weather_label)

# %%
weather_rentals = (
    day_df.groupby('weather_label')['cnt']
    .mean()
    .sort_values(ascending=False)
)

plt.figure(figsize=(8,5))

sns.barplot(
    x=weather_rentals.index,
    y=weather_rentals.values,
    color='#4C72B0'
)

plt.title('Rata-rata Penyewaan Berdasarkan Kondisi Cuaca')
plt.xlabel('Kondisi Cuaca')
plt.ylabel('Rata-rata Penyewaan')

plt.show()

# %% [markdown]
# ### Conclusion Pertanyaan 1
#
# Cuaca memiliki pengaruh besar terhadap jumlah penyewaan sepeda. Kondisi cuaca cerah menghasilkan jumlah penyewaan tertinggi.

# %% [markdown]
# ## Pertanyaan 2:
# Pada jam berapa jumlah penyewaan sepeda mencapai puncak tertinggi?

# %%
hourly_rentals = hour_df.groupby('hr')['cnt'].mean()

plt.figure(figsize=(10,5))

sns.lineplot(
    x=hourly_rentals.index,
    y=hourly_rentals.values,
    marker='o'
)

plt.title('Rata-rata Penyewaan Sepeda per Jam')
plt.xlabel('Jam')
plt.ylabel('Rata-rata Penyewaan')

plt.show()

# %% [markdown]
# ### Conclusion Pertanyaan 2
#
# Penyewaan sepeda paling tinggi terjadi pada pagi dan sore hari, terutama saat jam berangkat dan pulang kerja.

# %% [markdown]
# # Analisis Lanjutan (Opsional)
#
# Analisis tambahan dilakukan menggunakan teknik binning untuk mengelompokkan jam ke dalam kategori waktu tertentu.

# %%
hour_df['time_category'] = pd.cut(
    hour_df['hr'],
    bins=[0,6,12,18,24],
    labels=['Dini Hari','Pagi','Siang','Malam'],
    include_lowest=True
)

# %%
hour_df.groupby('time_category')['cnt'].mean().sort_values(ascending=False)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16748\1498632541.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   hour_df.groupby('time_category')['cnt'].mean().sort_values(ascending=False)
# time_category
# Siang        324.137143
# Pagi         237.589044
# Malam        185.806868
# Dini Hari     32.321736
# Name: cnt, dtype: float64

# %% [markdown]
# ### Insight Analisis Lanjutan
#
# Kategori waktu pagi dan sore memiliki rata-rata penyewaan sepeda tertinggi.

# %% [markdown]
# # Conclusion
#
# ## Pertanyaan 1
#
# Kondisi cuaca sangat memengaruhi jumlah penyewaan sepeda. Cuaca cerah menghasilkan jumlah penyewaan tertinggi.
#
# ## Pertanyaan 2
#
# Puncak jumlah penyewaan sepeda terjadi pada pukul 17.00 dengan rata-rata penyewaan tertinggi mencapai lebih dari 460 penyewaan per jam. Selain itu, terjadi peningkatan penyewaan pada jam sibuk lainnya, seperti pukul 08.00 pagi, yang menunjukkan bahwa layanan bike sharing paling banyak digunakan saat jam berangkat dan pulang kerja.

# %% [markdown]
# # Recommendation
#
# 1. Menambah jumlah sepeda pada jam sibuk untuk menghindari kekurangan unit.
#
# 2. Memberikan promo atau diskon saat kondisi cuaca buruk agar jumlah penyewaan tetap stabil.

# %%
hour_df.to_csv('dashboard/main_data.csv', index=False)
